# %%
import folium

# mapobj = folium.Map(location=[23.0204741,72.4149266],zoom_start=6)
# folium.Marker(location=[23.0204741,72.4149266],popup=folium.Popup('<i>The centre of city'),tooltip='Maru Amdavad').add_to(mapobj)

mapobj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edc02cfde84d1f1e00db6eb3bc45b3ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edc02cfde84d1f1e00db6eb3bc45b3ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edc02cfde84d1f1e00db6eb3bc45b3ea = L.map(
#                 &quot;map_edc02cfde84d1f1e00db6eb3bc45b3ea&quot;,
#                 {
#                     center: [23.0204741, 72.4149266],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c09a47ce0b389267555bceb5cefbf20 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_edc02cfde84d1f1e00db6eb3bc45b3ea);
#
#
#             var marker_88c7c3b5587d5a92113d1dfe64ce18b4 = L.marker(
#                 [23.0204741, 72.4149266],
#                 {}
#             ).addTo(map_edc02cfde84d1f1e00db6eb3bc45b3ea);
#
#
#         var popup_60532dc62173c540323e455a3877d4ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13a2f9a473f1747cb42553acc37762aa = $(`&lt;div id=&quot;html_13a2f9a473f1747cb42553acc37762aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;The centre of city&lt;/div&gt;`)[0];
#                 popup_60532dc62173c540323e455a3877d4ac.setContent(html_13a2f9a473f1747cb42553acc37762aa);
#
#
#
#         marker_88c7c3b5587d5a92113d1dfe64ce18b4.bindPopup(popup_60532dc62173c540323e455a3877d4ac)
#         ;
#
#
#
#
#             marker_88c7c3b5587d5a92113d1dfe64ce18b4.bindTooltip(
#                 `&lt;div&gt;
#                      Maru Amdavad
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import pandas as pd

df = pd.read_csv('Police_Department_Incidents_-_Previous_Year__2016.csv')
df.shape
df.head()
df=df.loc[0:99,:]
df.shape

sanfran_map=folium.Map(location=[37.77,-122.42],zoom_start=12)
incidents = folium.map.FeatureGroup()

# for lat,lng in zip(df.Y,df.X):
#     incidents.add_child(folium.features.CircleMarker([lat,lng],radius=5,color='yellow',fill=True,fill_color='blue',fill_opacity=0.6))
    
# sanfran_map.add_child(incidents)
latitudes=list(df.Y)
longitudes=list(df.X)
labels=list(df.Category)

for lat,log,label in zip(latitudes,longitudes,labels) :
    folium.Marker([lat,log],popup=label).add_to(sanfran_map)
    
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08122d695a6c29f73706f9767ae0b746 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08122d695a6c29f73706f9767ae0b746&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08122d695a6c29f73706f9767ae0b746 = L.map(
#                 &quot;map_08122d695a6c29f73706f9767ae0b746&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a167b3f285cf9daf66a5a0005205bf6b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_08122d695a6c29f73706f9767ae0b746);
#
#
#             var marker_0978bec9d80a5e37a045e2c0a8ccb29c = L.marker(
#                 [37.775420706711, -122.40340479147899],
#                 {}
#             ).addTo(map_08122d695a6c29f73706f9767ae0b746);
#
#
#         var popup_90d7b784dcae29576c7a473b0776c91f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ddaf6a590cb566086fc39d58d46e118 = $(`&lt;div id=&quot;html_7ddaf6a590cb566086fc39d58d46e118&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_90d7b784dcae29576c7a473b0776c91f.setContent(html_7ddaf6a590cb566086fc39d58d46e118);
#
#
#
#         marker_0978bec9d80a5e37a045e2c0a8ccb29c.bindPopup(popup_90d7b784dcae29576c7a473b0776c91f)
#         ;
#
#
#
#
#             var marker_4fb6e7236df841dda469a6d80f18948d = L.marker(
#                 [37.775420706711, -122.40340479147899],
#                 {}
#             ).addTo(map_08122d695a6c29f73706f9767ae0b746);
#
#
#         var popup_03ebf3e446749a6c882599798133935d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c186c28f19fff016772535f7e0fca5ad = $(`&lt;div id=&quot;html_c186c28f19fff016772535f7e0fca5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_03ebf3e446749a6c882599798133935d.setContent(html_c186c28f19fff016772535f7e0fca5ad);
#
#
#
#         marker_4fb6e7236df841dda469a6d80f18948d.bindPopup(popup_03ebf3e446749a6c882599798133935d)
#         ;
#
#
#
#
#             var marker_6746f81bba3301a705719539b49218bd = L.marker(
#                 [37.729980967299596, -122.388856204292],
#                 {}
#             ).addTo(map_08122d695a6c29f73706f9767ae0b746);
#
#
#         var popup_d821803d0ebb9abea4e00b08f04c2ee9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7873ebdc5e65cb207f24b50e5b00a57 = $(`&lt;div id=&quot;html_a7873ebdc5e65cb207f24b50e5b00a57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_d821803d0ebb9abea4e00b08f04c2ee9.setContent(html_a7873ebdc5e65cb207f24b50e5b00a57);
#
#
#
#         marker_6746f81bba3301a705719539b49218bd.bindPopup(popup_d821803d0ebb9abea4e00b08f04c2ee9)
#         ;
#
#
#
#
#             var marker_f86e6c8bda918c8f47bc970991a3fb20 = L.marker(
#                 [37.78578837668879, -122.412970537591],
#                 {}
#             ).addTo(map_08122d695a6c29f73706f9767ae0b746);
#
#
#         var popup_4434286f97bfbace358bee897466e05f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3ae5223050da9e2c6a5aac73df2f913 = $(`&lt;div id=&quot;html_f3ae5223050da9e2c6a5aac73df2f913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_4434286f97bfbace358bee897466e05f.setContent(html_f3ae5223050da9e2c6a5aac73df2f913);
#
#
#
#         marker_f86e6c8bda918c8f47bc970991a3fb20.bindPopup(popup_4434286f97bfbace358bee897466e05f)
#         ;
#
#
#
#
#             var marker_a946b477dd6d1946ee0a9824f2d16f56 = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(map_08122d695a6c29f73706f9767ae0b746);
#
#
#         var popup_e2bb71f7173a5ea60b19c192e4c53c32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26f90efd08861416fc5c7f31a83b0962 = $(`&lt;div id=&quot;html_26f90efd08861416fc5c7f31a83b0962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_e2bb71f7173a5ea60b19c192e4c53c32.setContent(html_26f90efd08861416fc5c7f31a83b0962);
#
#
#
#         marker_a946b477dd6d1946ee0a9824f2d16f56.bindPopup(popup_e2bb71f7173a5ea60b19c192e4c53c32)
#         ;
#
#
#
#
#             var marker_4f21eeaa1802c977165e6ce171eb36ea = L.m

# %%
import pandas as pd
import folium

df = pd.read_csv('US_Unemployment_Oct2012.csv')
state_geo = ('us-states.json')
usa_state = folium.Map(location=[48,-102],zoom_start=4)

folium.Choropleth(geo_data=state_geo, name='choropleth', data=df, columns=['State','Unemployment'],key_on='feature.id',fill_color='YlGnBu',fill_opacity=0.7, line_opacity=0.2, legend_name='Unemployment scale').add_to(usa_state)
usa_state
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d52017760ec189bfeaa9d032a231d2f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d52017760ec189bfeaa9d032a231d2f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d52017760ec189bfeaa9d032a231d2f3 = L.map(
#                 &quot;map_d52017760ec189bfeaa9d032a231d2f3&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ea73fd75ee212bc6cf2604cf8906f3a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d52017760ec189bfeaa9d032a231d2f3);
#
#
#             var choropleth_953b9ef1ccb9d4b2692780e5419f3af8 = L.featureGroup(
#                 {}
#             ).addTo(map_d52017760ec189bfeaa9d032a231d2f3);
#
#
#         function geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;NE&quot;: case &quot;ND&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5 = L.geoJson(null, {
#                 onEachFeature: geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5_onEachFeature,
#
#                 style: geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5_styler,
#         });
#
#         function geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5_add (data) {
#             geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5
#                 .addData(data)
#                 .addTo(choropleth_953b9ef1ccb9d4b2692780e5419f3af8);
#         }
#             geo_json_57e94ed5ff2729fd5a2c00c8ce028ed5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt

s=set(STOPWORDS)
f = open('alice.txt',encoding='utf-8')
a = f.read()
a_wc = WordCloud(max_words=1000, stopwords=s,background_color='brown')
s.add('said')
a_wc.generate(a)

plt.figure(figsize=(12,10))

plt.axis('off')
plt.imshow(a_wc)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('auto-mpg.csv')
sns.regplot(x='mpg',y='acceleration',data=df,color='green',marker='+')
plt.xlabel('')
plt.ylabel('')
plt.title('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-d30d81533214> in <module>
# ----> 1 import seoborn as sns
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4
#       5 df=pd.read_csv('auto-mpg.csv')
#
# ModuleNotFoundError: No module named 'seoborn'
